# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 9.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip /content/gdrive/MyDrive/Website_Screens_v1_websitev1_yolov8.zip
# Out:
# Archive:  /content/gdrive/MyDrive/Website_Screens_v1_websitev1_yolov8.zip
#  extracting: README.dataset.txt
#  extracting: README.roboflow.txt
#  extracting: data.yaml
#    creating: test/
#    creating: test/images/
#  extracting: test/images/addons_mozilla_org_png_jpg.rf.2d282274da42d10c86dde8854d4036e7.jpg
#  extracting: test/images/adf_ly_png_jpg.rf.498ef080652af5c666330b59bc20c46e.jpg
#  extracting: test/images/advancedcustomfields_com_png_jpg.rf.8756afe05d0efe97fb8026e2e5e686b0.jpg
#  extracting: test/images/ajax_googleapis_com_png_jpg.rf.9d378f8406c51c4a8af2d468a9f90ec8.jpg
#  extracting: test/images/amazon_es_png_jpg.rf.bad9b2024510100922ffd9f7fe229d71.jpg
#  extracting: test/images/androidpolice_com_png_jpg.rf.ade35c9521cf93d76aaf07f58dafe3d2.jpg
#  extracting: test/images/animoto_com_png_jpg.rf.7c0f37ea5163fce0108b865f6f1c48d4.jpg
#  extracting: test/images/asus_com_png_jpg.rf.a805d5daeaf10005838806d4ad48b579.jpg
# ...

# %%
from ultralytics import YOLO

# model = YOLO("yolo")
model = YOLO('yolov8n.pt')
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 80.1MB/s]

# %%
# !nvidia-smi
# Out:
# Wed Dec 13 13:48:33 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/data.yaml epochs=90 imgsz=416
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 182MB/s]
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect \
mode=val \
model=/content/runs/detect/train/weights/best.pt \
data=/content/data.yaml
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
# val: Scanning /content/valid/labels.cache... 241 images, 0 backgrounds, 0 corrupt: 100% 241/241 [00:00<?, ?it/s]
# val: WARNING ⚠️ /content/valid/images/bandsintown_com_png_jpg.rf.1c41849b41d8974fabcbeee3a0bf25a2.jpg: 4 duplicate labels removed
# val: WARNING ⚠️ /content/valid/images/deondernemer_nl_png_jpg.rf.2dafbe327a5c9edb06be94abffc55ffe.jpg: 1 duplicate labels removed
# val: WARNING ⚠️ /content/valid/images/flickr_com_png_jpg.rf.7bcb7a09896aadbe54400333b82c1503.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /content/valid/images/foxnews_com_png_jpg.rf.04cd7516409e4e608c954c2af451eb6f.jpg: 2 duplicate labels removed
# val: WARNING ⚠️ /content/valid/images/g2a_com_png_jpg.rf.ec06d8f492ed250574f75837d291d483.jpg: 2 duplicate labels removed
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf = 0.25 source = /content/test/images
#data=/content/data.yaml
# check the results in predict folder
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/122 /content/test/images/addons_mozilla_org_png_jpg.rf.2d282274da42d10c86dde8854d4036e7.jpg: 416x416 14 buttons, 1 field, 9 headings, 5 images, 4 links, 12 texts, 16.5ms
# image 2/122 /content/test/images/adf_ly_png_jpg.rf.498ef080652af5c666330b59bc20c46e.jpg: 416x416 8 buttons, 1 field, 5 headings, 6 images, 2 links, 19 texts, 15.8ms
# image 3/122 /content/test/images/advancedcustomfields_com_png_jpg.rf.8756afe05d0efe97fb8026e2e5e686b0.jpg: 416x416 5 buttons, 4 headings, 1 iframe, 1 image, 1 link, 4 texts, 18.2ms
# image 4/122 /content/test/images/ajax_googleapis_com_png_jpg.rf.9d378f8406c51c4a8af2d468a9f90ec8.jpg: 416x416 3 buttons, 1 field, 3 headings, 5 links, 11 texts, 11.7ms
# ...

# %%
import shutil

# Replace 'folder_path' with the path of the folder you want to zip
folder_path = '/content/runs'

# Replace 'output_zip_path' with the desired path and name for the output zip file
output_zip_path = '/content/element_detection'

shutil.make_archive(output_zip_path, 'zip', folder_path)
# Out:
# '/content/element_detection.zip'

# %%
from google.colab import drive

drive.mount('/content/gdrive')

import shutil

# Replace 'source_file_path' with the path of the file in Colab
source_file_path = '/content/element_detection.zip'

# Replace 'destination_drive_path' with the destination path in Google Drive
destination_drive_path = '/content/gdrive/MyDrive/element_detection.zip'

shutil.copy(source_file_path, destination_drive_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# '/content/gdrive/MyDrive/element_detection.zip'

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf = 0.25 source = /content/8eba123f-1fe5-4eaa-baef-d8df73481eac-cover.png
#data=/content/data.yaml
# check the results in predict folder
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128680 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /content/8eba123f-1fe5-4eaa-baef-d8df73481eac-cover.png: 224x416 6 buttons, 6 fields, 2 headings, 14 images, 12 texts, 193.6ms
# Speed: 1.5ms preprocess, 193.6ms inference, 4.0ms postprocess per image at shape (1, 3, 224, 416)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
